# %% [markdown]
# <a href="https://colab.research.google.com/github/ashu0109/Cognorise_InfoTech_Datascience/blob/main/Credit%20Card%20Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.metrics import accuracy_score, classification_report
import pickle
import warnings

warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', 500)

# Loading Dataset which is CSV file in my Drive
# Connecting to the drive for dataset

df_train = pd.read_csv('/content/fraudTest.csv', low_memory=False, index_col=0)
df_test = pd.read_csv('/content/fraudTest.csv', low_memory=False, index_col=0)

# Prints the shapes of the training and test DataFrames to check the number of rows and columns.

df_train.shape
df_test.shape
# Out:
# (58343, 22)

# %%
# Checks if the columns in the training and test DataFrames are the same.

list(df_train.columns) == list(df_test.columns)

# Prints the shape of the combined DataFrame.

df = pd.concat([df_train, df_test],ignore_index=True)
df.shape
# Out:
# (116686, 22)

# %%
# Counts the occurrences of each unique value in the 'is_fraud' column, providing insight into the class distribution.

df.is_fraud.value_counts()
# Out:
# 0.0    116216
# 1.0       468
# Name: is_fraud, dtype: int64

# %%
# specified columns from the DataFrame, removing unnecessary features.

def clean_df(df):
    return df.drop(['cc_num','first', 'last', 'street', 'city', 'state', 'zip', 'dob', 'trans_num','trans_date_trans_time'],axis=1)

# clean the DataFrame and prints the first two rows.

df = clean_df(df)
df.head(2)
# Out:
#                 merchant       category    amt gender      lat      long  \
# 0  fraud_Kirlin and Sons  personal_care   2.86      M  33.9659  -80.9355
# 1   fraud_Sporer-Keebler  personal_care  29.84      F  40.3207 -110.4360
#
#    city_pop                     job     unix_time  merch_lat  merch_long  \
# 0    333497     Mechanical engineer  1.371817e+09  33.986391  -81.200714
# 1       302  Sales professional, IT  1.371817e+09  39.450498 -109.960431
#
#    is_fraud
# 0       0.0
# 1       0.0

# %%
df.head()
# Out:
#                                merchant        category    amt gender  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86      M
# 1                  fraud_Sporer-Keebler   personal_care  29.84      F
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28      F
# 3                     fraud_Haley Group        misc_pos  60.05      M
# 4                 fraud_Johnston-Casper          travel   3.19      M
#
#        lat      long  city_pop                     job     unix_time  \
# 0  33.9659  -80.9355    333497     Mechanical engineer  1.371817e+09
# 1  40.3207 -110.4360       302  Sales professional, IT  1.371817e+09
# 2  40.6729  -73.5365     34496       Librarian, public  1.371817e+09
# 3  28.5697  -80.8191     54767            Set designer  1.371817e+09
# 4  44.2529  -85.0170      1126      Furniture designer  1.371817e+09
#
#    merch_lat  merch_long  is_fraud
# 0  33.986391  -81.200714       0.0
# 1  39.450498 -109.960431       0.0
# 2  40.495810  -74.196111       0.0
# 3  28.812398  -80.883061       0.0
# 4  44.959148  -85.884734       0.0

# %%
# Splits the DataFrame into training and testing sets using train_test_split.

train, test = train_test_split(df, test_size=0.2, shuffle=True, random_state=42)
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)
train.shape, test.shape
# Out:
# ((93348, 12), (23338, 12))

# %%
# Defines a function encode to label encode categorical columns in the DataFrame

def encode(df):
    df_obj = df.select_dtypes(include=['object'])
    encoders = {}
    for col in df_obj.columns:
        encoder = LabelEncoder()
        df[col] = encoder.fit_transform(df[col])
        encoders[col] = encoder
    with open('LE_mdl_v1.pkl', 'wb') as f:
        pickle.dump(encoders, f)
    return df

train = encode(train)
train.head(2)
# Out:
#    merchant  category    amt  gender      lat     long  city_pop  job  \
# 0       128         1  54.09       0  39.1657 -84.2330     31394  222
# 1       152         0  12.25       1  40.0987 -84.6342     22930  277
#
#       unix_time  merch_lat  merch_long  is_fraud
# 0  1.372536e+09  39.270535  -83.537479       0.0
# 1  1.372425e+09  39.702252  -83.908581       0.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['merchant'].plot(kind='hist', bins=20, title='merchant')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['category'].plot(kind='hist', bins=20, title='category')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['amt'].plot(kind='hist', bins=20, title='amt')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['gender'].plot(kind='hist', bins=20, title='gender')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='merchant', y='category', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='category', y='amt', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='amt', y='gender', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='gender', y='lat', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['merchant']
#   ys = series['category']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('merchant', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('merchant')
# _ = plt.ylabel('category')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['merchant']
#   ys = series['amt']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('merchant', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('merchant')
# _ = plt.ylabel('amt')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['merchant']
#   ys = series['long']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('merchant', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('merchant')
# _ = plt.ylabel('long')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['merchant']
#   ys = series['city_pop']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('merchant', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('merchant')
# _ = plt.ylabel('city_pop')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['merchant'].plot(kind='line', figsize=(8, 4), title='merchant')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['category'].plot(kind='line', figsize=(8, 4), title='category')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['amt'].plot(kind='line', figsize=(8, 4), title='amt')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['gender'].plot(kind='line', figsize=(8, 4), title='gender')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
x = train.drop(columns=['is_fraud'])
y = train['is_fraud']
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, shuffle=True, random_state=42)

# %%
# Initializes three machine learning models: Logistic Regression, Random Forest, and Decision Tree.

model1 = LogisticRegression()
model2 = RandomForestClassifier()
model3 = DecisionTreeClassifier()

# %%
# Defines a function model_train to train a given model, make predictions, print accuracy and classification report

def model_train(model, x_train, y_train, x_test, y_test):
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    print('Accuracy Score: ',accuracy_score(y_test,y_pred))
    print(classification_report(y_test,y_pred))
    with open(str(model)[:3] + '_mdl.pkl', 'wb') as f:
        pickle.dump(model,f)
